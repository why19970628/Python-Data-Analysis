# %%
# -*- coding:utf-8 -*-
#数据探索分析

import pandas as pd
import numpy as np
from pandas import DataFrame,Series

# %%
inputfile1 = 'discdata.xls'
data = pd.read_excel(inputfile1)
data.head()
# Out:
#   SYS_NAME     NAME  TARGET_ID DESCRIPTION ENTITY         VALUE COLLECTTIME
# 0   财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  3.427079e+07  2014-10-01
# 1   财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  8.026259e+07  2014-10-01
# 2   财务管理系统  CWXT_DB        183        磁盘容量    C:\  5.232332e+07  2014-10-01
# 3   财务管理系统  CWXT_DB        183        磁盘容量    D:\  1.572833e+08  2014-10-01
# 4   财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  3.432890e+07  2014-10-02

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 188 entries, 0 to 187
# Data columns (total 7 columns):
# SYS_NAME       188 non-null object
# NAME           188 non-null object
# TARGET_ID      188 non-null int64
# DESCRIPTION    188 non-null object
# ENTITY         188 non-null object
# VALUE          188 non-null float64
# COLLECTTIME    188 non-null datetime64[ns]
# dtypes: datetime64[ns](1), float64(1), int64(1), object(4)
# memory usage: 10.4+ KB

# %%
d = data[(data['ENTITY']=='C:\\') & (data['TARGET_ID']==184 )]
d
# Out:
#     SYS_NAME     NAME  TARGET_ID DESCRIPTION ENTITY        VALUE COLLECTTIME
# 0     财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  34270787.33  2014-10-01
# 4     财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  34328899.02  2014-10-02
# 8     财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  34327553.50  2014-10-03
# 12    财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  34288672.21  2014-10-04
# 16    财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  34190978.41  2014-10-05
# 20    财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  34187614.43  2014-10-06
# 24    财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  34285280.22  2014-10-07
# 28    财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  34290578.41  2014-10-08
# 32    财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  33211870.40  2014-10-09
# 36    财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  33249253.87  2014-10-10
# 40    财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  33253832.53  2014-10-11
# 44    财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  34328058.03  2014-10-12
# 48    财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  34328674.80  2014-10-13
# 52    财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  34234933.61  2014-10-14
# 56    财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  34022726.41  2014-10-15
# 60    财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  35016309.47  2014-10-16
# 64    财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  34981412.82  2014-10-17
# 68    财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  34828871.38  2014-10-18
# 72    财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  34832868.75  2014-10-19
# 76    财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  34843372.75  2014-10-20
# 80    财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  34847749.42  2014-10-21
# 84    财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  34829775.93  2014-10-22
# 88    财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  34824290.49  2014-10-23
# 92    财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  34827149.93  2014-10-24
# 96    财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  34820088.89  2014-10-25
# 100   财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  34776030.47  2014-10-26
# 104   财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  34667722.51  2014-10-27
# 108   财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  35705011.09  2014-10-28
# 112   财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  35594215.37  2014-10-29
# 116   财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  35411287.07  2014-10-30
# 120   财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  35389055.02  2014-10-31
# 124   财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  35385076.36  2014-11-01
# 128   财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  35462038.02  2014-11-02
# 132   财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  35486821.33  2014-11-03
# 136   财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  35471088.77  2014-11-04
# 140   财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  35547564.55  2014-11-05
# 144   财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  35606941.11  2014-11-06
# 148   财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  35546714.13  2014-11-07
# 152   财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  35510966.73  2014-11-08
# 156   财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  35491498.51  2014-11-09
# 160   财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  35601990.55  2014-11-10
# 164   财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  35687972.60  2014-11-11
# 168   财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  35704312.58  2014-11-12
# 172   财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  35704980.73  2014-11-13
# 176   财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  34570385.45  2014-11-14
# 180   财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  34673820.69  2014-11-15
# 184   财务管理系统  CWXT_DB        184     磁盘已使用大小    C:\  34793245.31  2014-11-16

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
plt.rc('figure',figsize=(9,7))
import datetime
import matplotlib.dates as mdates
plt.rcParams['font.sans-serif']=['SimHei']
plt.rcParams['axes.unicode_minus']= False

# %%
fig  = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.set_title(u"C盘已使用空间的时序图")
# ax.set_xlabel(u'日期')
ax.set(xlabel=u'日期',ylabel=u'磁盘使用大小')
# 图上时间间隔显示为10天
ax.xaxis.set_major_locator(mdates.DayLocator(bymonthday=range(1,32), interval=10)) 
ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m-%d"))
plt.subplots_adjust(bottom=0.13,top=0.95)
ax.plot(d['COLLECTTIME'],d['VALUE'],'ro-',)

fig.autofmt_xdate() #自动根据标签长度进行旋转
'''for label in ax.xaxis.get_ticklabels():   #此语句完成功能同上
       label.set_rotation(45)
'''
plt.savefig('c.jpg')
plt.show()

# %%
d1 = data[(data['ENTITY']=='D:\\') & (data['TARGET_ID']==184 )]
d1
# Out:
#     SYS_NAME     NAME  TARGET_ID DESCRIPTION ENTITY        VALUE COLLECTTIME
# 1     财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  80262592.65  2014-10-01
# 5     财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  83200151.65  2014-10-02
# 9     财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  83208320.00  2014-10-03
# 13    财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  83099271.65  2014-10-04
# 17    财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  82765171.65  2014-10-05
# 21    财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  82522895.00  2014-10-06
# 25    财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  82590885.00  2014-10-07
# 29    财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  82368173.30  2014-10-08
# 33    财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  82172263.30  2014-10-09
# 37    财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  81922685.00  2014-10-10
# 41    财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  84844722.95  2014-10-11
# 45    财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  84769868.90  2014-10-12
# 49    财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  84558703.40  2014-10-13
# 53    财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  84207166.80  2014-10-14
# 57    财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  84042911.90  2014-10-15
# 61    财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  84129516.15  2014-10-16
# 65    财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  83877754.85  2014-10-17
# 69    财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  83887520.40  2014-10-18
# 73    财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  83538509.75  2014-10-19
# 77    财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  86483653.00  2014-10-20
# 81    财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  82496743.30  2014-10-21
# 85    财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  82300356.65  2014-10-22
# 89    财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  82130251.65  2014-10-23
# 93    财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  84844587.65  2014-10-24
# 97    财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  84845444.65  2014-10-25
# 101   财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  84684911.05  2014-10-26
# 105   财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  84500606.35  2014-10-27
# 109   财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  84145461.25  2014-10-28
# 113   财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  84172525.10  2014-10-29
# 117   财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  83957818.70  2014-10-30
# 121   财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  83684789.75  2014-10-31
# 125   财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  86485366.95  2014-11-01
# 129   财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  86454023.45  2014-11-02
# 133   财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  86127041.70  2014-11-03
# 137   财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  86161390.40  2014-11-04
# 141   财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  85938933.90  2014-11-05
# 145   财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  85645056.50  2014-11-06
# 149   财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  85272926.05  2014-11-07
# 153   财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  88110097.75  2014-11-08
# 157   财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  88128626.65  2014-11-09
# 161   财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  88075997.75  2014-11-10
# 165   财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  87753526.65  2014-11-11
# 169   财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  87249335.55  2014-11-12
# 173   财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  86986142.20  2014-11-13
# 177   财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  86678240.00  2014-11-14
# 181   财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  89766600.00  2014-11-15
# 185   财务管理系统  CWXT_DB        184     磁盘已使用大小    D:\  89377527.25  2014-11-16

# %%
fig  = plt.figure()
ax = fig.add_subplot(1,1,1)
ax.set_title(u"D盘已使用空间的时序图")
# ax.set_xlabel(u'日期')
ax.set(xlabel=u'日期',ylabel=u'磁盘使用大小')
# 图上时间间隔显示为10天
ax.xaxis.set_major_locator(mdates.DayLocator(bymonthday=range(1,32), interval=10)) 
ax.xaxis.set_major_formatter(mdates.DateFormatter("%Y-%m-%d"))
plt.subplots_adjust(bottom=0.13,top=0.95)
ax.plot(d1['COLLECTTIME'],d1['VALUE'],'g*-',)

fig.autofmt_xdate() #自动根据标签长度进行旋转
'''for label in ax.xaxis.get_ticklabels():   #此语句完成功能同上
       label.set_rotation(45)
'''
plt.savefig('d.jpg')
plt.show()

# %%
# 通过图中可以发现，磁盘的使用情况都不具有周期性，表现出缓慢性增长，呈现趋势性。因此，可以初步确认数据是非平稳的
